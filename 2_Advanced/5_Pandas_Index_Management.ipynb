# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_serbia = df[df.job_country == 'Serbia']
df_serbia.reset_index(inplace=True)
df_serbia = df_serbia.drop(columns='index')
df_serbia.set_index('search_location', inplace=True)
df_serbia.reset_index(inplace=True)
df_serbia
# Out:
#      search_location        job_title_short  \
# 0             Serbia         Data Scientist
# 1             Serbia          Data Engineer
# 2             Serbia  Senior Data Scientist
# 3             Serbia       Business Analyst
# 4             Serbia           Data Analyst
# ...              ...                    ...
# 1021          Serbia         Data Scientist
# 1022          Serbia           Data Analyst
# 1023          Serbia         Data Scientist
# 1024          Serbia          Data Engineer
# 1025          Serbia       Business Analyst
#
#                                               job_title      job_location  \
# 0                         Data Scientist (DataLab Team)          Anywhere
# 1                             Junior BI & Data Engineer  Belgrade, Serbia
# 2                                 Senior Data Scientist  Belgrade, Serbia
# 3                         Business Intelligence Analyst  Belgrade, Serbia
# ...
